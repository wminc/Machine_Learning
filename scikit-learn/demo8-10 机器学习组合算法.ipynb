# %%
import api

# %%
fsr0 = 'tmp/ccpp_'

mlst1 = ['line','log','bayes','knn','forest','dtree','svm','mlp','mlpreg']
mlst2 = ['forest','dtree','svm']
mlst3 = ['line','log','bayes']
mlst4 = ['line','forest','dtree']

# %%
x_test = api.ai_f_datRd010(fsr0+'xtest.csv')
y_test = api.ai_f_datRd010(fsr0+'ytest.csv',1)

# %%
api.xmodel = {}
api.ai_f_mxRdlst(fsr0,mlst1)

api.mx_mul(mlst1,x_test,y_test,yk0=1,fgInt=False,fgDebug=False)
# Out:
# (75.4180602006689,
#           AT      V       AP     RH  y_test        y_sum      y_pred      ysub  \
#  0     17.80  43.72  1008.71  78.50     459  4129.210562  458.801174  0.198826
#  1     29.60  71.14  1011.46  52.69     431  3894.188121  432.687569 -1.687569
#  2     11.06  36.71  1021.67  80.44     474  4274.112398  474.901378 -0.901378
#  3     30.06  67.25  1017.63  53.59     435  3907.799396  434.199933  0.800067
#  4     19.88  47.03  1012.27  91.99     456  4083.465457  453.718384  2.281616
#  ...     ...    ...      ...    ...     ...          ...         ...       ...
#  2387  26.34  69.45  1013.87  54.15     438  3935.226168  437.247352  0.752648
#  2388  25.06  64.63  1020.66  54.93     447  3970.115963  441.123996  5.876004
#  2389   8.34  40.96  1023.28  89.45     484  4315.503506  479.500390  4.499610
#  2390  26.69  70.36  1006.82  68.29     435  3909.407426  434.378603  0.621397
#  2391  17.46  53.29  1018.07  91.01     458  4067.895409  451.988379  6.011621
#
# ...

# %%
api.mx_mul(mlst2,x_test,y_test,yk0=1,fgInt=False,fgDebug=False)
# Out:
# (79.38963210702342,
#           AT      V       AP     RH  y_test  y_sum      y_pred      ysub  \
#  0     17.80  43.72  1008.71  78.50     459   1362  454.000000  5.000000
#  1     29.60  71.14  1011.46  52.69     431   1297  432.333333 -1.333333
#  2     11.06  36.71  1021.67  80.44     474   1421  473.666667  0.333333
#  3     30.06  67.25  1017.63  53.59     435   1303  434.333333  0.666667
#  4     19.88  47.03  1012.27  91.99     456   1343  447.666667  8.333333
#  ...     ...    ...      ...    ...     ...    ...         ...       ...
#  2387  26.34  69.45  1013.87  54.15     438   1308  436.000000  2.000000
#  2388  25.06  64.63  1020.66  54.93     447   1333  444.333333  2.666667
#  2389   8.34  40.96  1023.28  89.45     484   1447  482.333333  1.666667
#  2390  26.69  70.36  1006.82  68.29     435   1307  435.666667 -0.666667
#  2391  17.46  53.29  1018.07  91.01     458   1349  449.666667  8.333333
#
#           ysub2  y_test_div     ysubk  y_pred1  y_pred2  y_pred3
# ...

# %%
api.mx_mul(mlst3,x_test,y_test,yk0=1,fgInt=False,fgDebug=False)
# Out:
# (64.33946488294315,
#           AT      V       AP     RH  y_test        y_sum      y_pred      ysub  \
#  0     17.80  43.72  1008.71  78.50     459  1388.333058  462.777686 -3.777686
#  1     29.60  71.14  1011.46  52.69     431  1299.924755  433.308252 -2.308252
#  2     11.06  36.71  1021.67  80.44     474  1422.852710  474.284237 -0.284237
#  3     30.06  67.25  1017.63  53.59     435  1304.206537  434.735512  0.264488
#  4     19.88  47.03  1012.27  91.99     456  1384.572842  461.524281 -5.524281
#  ...     ...    ...      ...    ...     ...          ...         ...       ...
#  2387  26.34  69.45  1013.87  54.15     438  1312.686789  437.562263  0.437737
#  2388  25.06  64.63  1020.66  54.93     447  1324.680345  441.560115  5.439885
#  2389   8.34  40.96  1023.28  89.45     484  1436.917924  478.972641  5.027359
#  2390  26.69  70.36  1006.82  68.29     435  1309.065692  436.355231 -1.355231
#  2391  17.46  53.29  1018.07  91.01     458  1356.443839  452.147946  5.852054
#
# ...

# %%
api.mx_mul(mlst4,x_test,y_test,yk0=1,fgInt=False,fgDebug=False)
# Out:
# (82.65050167224081,
#           AT      V       AP     RH  y_test        y_sum      y_pred      ysub  \
#  0     17.80  43.72  1008.71  78.50     459  1367.333058  455.777686  3.222314
#  1     29.60  71.14  1011.46  52.69     431  1298.924755  432.974918 -1.974918
#  2     11.06  36.71  1021.67  80.44     474  1421.852710  473.950903  0.049097
#  3     30.06  67.25  1017.63  53.59     435  1303.206537  434.402179  0.597821
#  4     19.88  47.03  1012.27  91.99     456  1354.572842  451.524281  4.475719
#  ...     ...    ...      ...    ...     ...          ...         ...       ...
#  2387  26.34  69.45  1013.87  54.15     438  1313.686789  437.895596  0.104404
#  2388  25.06  64.63  1020.66  54.93     447  1327.680345  442.560115  4.439885
#  2389   8.34  40.96  1023.28  89.45     484  1449.917924  483.305975  0.694025
#  2390  26.69  70.36  1006.82  68.29     435  1309.065692  436.355231 -1.355231
#  2391  17.46  53.29  1018.07  91.01     458  1364.443839  454.814613  3.185387
#
# ...
